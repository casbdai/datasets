# %% [markdown]
# # Authentication

# %% [markdown]
# Read secrets

# %%
CLIENT_ID = "98cdd6d612d54a6fa2b0f9e65f48a323"
CLIENT_SECRET = "d5550859d62640eaacd12d86c8d0d351"

# %% [markdown]
# Request token
#
# - url: The endpoint of the API
# - headers: Information for the HTTP request, such as authentication
# - data: The payload of the request - all other information such as requested IDs, queries, ...

# %%
import requests
import base64

url = "https://accounts.spotify.com/api/token"


credentialsString = f"{CLIENT_ID}:{CLIENT_SECRET}" # string
credentialsBytes = credentialsString.encode("utf-8") # bytes
credentialsBytesBase64 = base64.b64encode(credentialsBytes) # bytes base64 encoded
credentialsStringBase64 = credentialsBytesBase64.decode("utf-8") # string base64 encoded

headers = {"Authorization": f"Basic {credentialsStringBase64}"}
data = {"grant_type": "client_credentials"}

r = requests.post(url, headers=headers, data=data)

# Extract the token
token = r.json()["access_token"]
token
# Out:
# 'BQDcCcfWEz1IKPaJiidgua-OJgCWzMrT1cM3s8ZzFZIaTYnVku38wwqEWZE_A99RncWelDNgTHFlEftg3DKMt13vwf-sJ-5ltQwnyIDVQ8IHrgziiTs'

# %% [markdown]
# # Getting Track Information
#
# In this section we will utilize the [GET /playlist/{playlist_id}/tracks](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-playlists-tracks) endpoint

# %% [markdown]
# For this endpoint, the spotify API requests all information in the url except for the authorization which remains in the header
#
# The url we will use is https://api.spotify.com/v1/playlists/{playlist_id}/tracks?fields={fields}
#
# Basics for urls
# - Protocol. http:// or https://
#     - https:// ensures encrypton of the traffic between client and surver using SSL/TLS. Never enter your password in a http:// website, as it will be sent unencrypted through the network (e.g. WLAN)
# - Domain. The identifying part. A Top-level domain (.com) is split with a (.) from the domain name (spotify).
#     - spotify.com: Only one entity can control spotify.com so we know we can trust the URL
#     - Before entering your password check for the domain, it is the only part that can not be manipulated
# - Sub-Domain. Everything before the second last (.): here (api.). It helps developers seperating traffic to different servers. Spotify uses different sub-domains
#     - api.spotify.com for the API
#     - open.spotify.com for the webplayer
#     - developer.spotify.com for documentation
#     - www.spotify.com is a subdomain too, it redirects to open.spotify.com
# - Routes. Everything between the first (/) and the (?). On a server (e.g. api.spotify.com) it describes where to find the resource.
#     - /v1: Version 1 of the API
#     - /v1/playlists: We are requesting playlist information
#     - /v1/playlists/{playlist_id}: Spotify provides a route for each playlist based on the playlist id. The curly brackets indicate a placeholder
#     - /v1/playlists/{playlist_id}/tracks: We are requesting track information for that playlist
# - Variables. Everything after the (?).
#     - fields: A variable used by spotify to specify which information should be returned to the client

# %%
playlist_id = "1qvW13XhfMMZMlzQx362HR"
fields = "next,items(track(artists(id,name),album(id,name),id,name))"

playlist_url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks?fields={fields}"

headers = {"Authorization": "Bearer " + token}

# Get the playlist's tracks informations
r = requests.get(url=playlist_url, headers=headers)

# %% [markdown]
# The response object contains the result of our request. As no error has been trown, we know that the request reached the server, we got a response back and had no connectivity issues. Howerever, the response could have been unsuccessful, e.g., with a status code 401: Unauthorized or 404: Not Found

# %%
print(r.status_code)
print(r.content)
# Out:
# 200
# b'{\n  "items" : [ {\n    "track" : {\n      "album" : {\n        "id" : "0c6GZXLOQNRRfoJSCraLwc",\n        "name" : "Pendulum"\n      },\n      "artists" : [ {\n        "id" : "0tquhVod10o2zf1ht2aVoz",\n        "name" : "Elior"\n      }, {\n        "id" : "5MvvhhTGyd2iGzaksZpLEt",\n        "name" : "eaup"\n      } ],\n      "id" : "5XfGPtiNkoPkeK00QTEHCb",\n      "name" : "Pendulum"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "3W1TKjeKQawzmVlBGr9eOr",\n        "name" : "Cheer Up"\n      },\n      "artists" : [ {\n        "id" : "5MvvhhTGyd2iGzaksZpLEt",\n        "name" : "eaup"\n      } ],\n      "id" : "0CVT6rpAdkDm4NKLdv7E9g",\n      "name" : "Cheer Up"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "04YdOVml7kXJN985zOOHPX",\n        "name" : "Endless Road"\n      },\n      "artists" : [ {\n        "id" : "2RBJhPBOr8mI5evwaL4HR3",\n        "name" : "Ghostnaut"\n      }, {\n        "id" : "1XFN3VcuKr4tsTtQlRiTgK",\n        "name" : "Mondo Loops"\n      }, {\n        "id" : "773SnwBYAvo9JlHuulUvMu",\n        "name" : "Lunath"\n      } ],\n      "id" : "1Kqx9kj7twQEexWCa4WHUZ",\n      "name" : "Endless Road"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "4WjETwIOQcthrTokTKIOvL",\n        "name" : "II"\n      },\n      "artists" : [ {\n        "id" : "6CzaYsf8RIrCHNDhFGSfgm",\n        "name" : "Havana Swim Club"\n      }, {\n        "id" : "5YNnmXnEEEJM0ArqHDSyET",\n        "name" : "Lonely Benson"\n      } ],\n      "id" : "4ertsRlco2bn3dWqY41sxS",\n      "name" : "Fantasy"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "6tlATjYhVr3LhLZGBjtQmB",\n        "name" : "Ovina"\n      },\n      "artists" : [ {\n        "id" : "14xurMk6IfCAqEzI1txycG",\n        "name" : "Prinz Leo"\n      }, {\n        "id" : "6VRAgC9krW0Ewz16KmTvZK",\n        "name" : "THAT KINDA VIBE"\n      } ],\n      "id" : "0fO196iK1nt9tdoOLsn1pq",\n      "name" : "Ovina"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "3y6vDJUUxKT9zZ1veqouMp",\n        "name" : "Cosmic Sunrise"\n      },\n      "artists" : [ {\n        "id" : "6asrIoUCBS9LTWl26Bo0fT",\n        "name" : "Carter Fox"\n      }, {\n        "id" : "005IIda5UkmCXokco7snZg",\n        "name" : "Steve Honz"\n      } ],\n      "id" : "7B0TvH0YA2nHfoccgRRTq1",\n      "name" : "Cosmic Sunrise"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "0iCRip4xkOrwKejPxO13s0",\n        "name" : "Elevenses"\n      },\n      "artists" : [ {\n        "id" : "32lJwqZ7Tf3hp6oYnr9hSh",\n        "name" : "Second Breakfast"\n      } ],\n      "id" : "41PfG9u4RTTyMXMw4T9x7T",\n      "name" : "beaming light"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "2i5wQo2Lp1t1fZZj225vBH",\n        "name" : "voiceless"\n      },\n      "artists" : [ {\n        "id" : "6gQzBYh1naIayoJA567ATQ",\n        "name" : "Criibaby"\n      }, {\n        "id" : "0xbNWCGKRUJ5wILr2dvQEO",\n        "name" : "Surfer Dave"\n      } ],\n      "id" : "61qrps9b5q9THQEjIw9J64",\n      "name" : "home"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "7fgzEkEfuOQ8O12sjk275l",\n        "name" : "The Hi-Lofi Chronicles, Vol. 1"\n      },\n      "artists" : [ {\n        "id" : "4W2Wr4txFhXLLGEXGwBa3J",\n        "name" : "Zero-B1"\n      } ],\n      "id" : "5gxZyok3wk3IPyDIIuPKKB",\n      "name" : "Everything Bliss"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "2tZmQ6IBCmSWKlvkpGh0Ph",\n        "name" : "springtime lonely"\n      },\n      "artists" : [ {\n        "id" : "2P08fd6pngLcSXUAGpsJSz",\n        "name" : "Boy Illum"\n      } ],\n      "id" : "598YdJ5dReNQn3GYDdhnY9",\n      "name" : "springtime lonely"\n    }\n  }, {\n    "track" : {\n      "album" : {\n        "id" : "6APc76iPQ69N4dKAceKkMn",\n        "name" : "Red Sky"\n      },\n      "artists" : [ {\n        "id" : "1z1vBZzW0Id2qR0FrFr5Yg",\n        "name" : "Sbeady"\n      } ],\n      "id" : "135qlCw4Xds13ElAIVgDGf",\n   ...

# %% [markdown]
# We can parse the content in a python dictionary using the .json() method

# %%
r_json = r.json()
r_json
# Out:
# {'items': [{'track': {'album': {'id': '0c6GZXLOQNRRfoJSCraLwc',
#      'name': 'Pendulum'},
#     'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '5XfGPtiNkoPkeK00QTEHCb',
#     'name': 'Pendulum'}},
#   {'track': {'album': {'id': '3W1TKjeKQawzmVlBGr9eOr', 'name': 'Cheer Up'},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '0CVT6rpAdkDm4NKLdv7E9g',
#     'name': 'Cheer Up'}},
#   {'track': {'album': {'id': '04YdOVml7kXJN985zOOHPX', 'name': 'Endless Road'},
#     'artists': [{'id': '2RBJhPBOr8mI5evwaL4HR3', 'name': 'Ghostnaut'},
#      {'id': '1XFN3VcuKr4tsTtQlRiTgK', 'name': 'Mondo Loops'},
#      {'id': '773SnwBYAvo9JlHuulUvMu', 'name': 'Lunath'}],
#     'id': '1Kqx9kj7twQEexWCa4WHUZ',
#     'name': 'Endless Road'}},
#   {'track': {'album': {'id': '4WjETwIOQcthrTokTKIOvL', 'name': 'II'},
#     'artists': [{'id': '6CzaYsf8RIrCHNDhFGSfgm', 'name': 'Havana Swim Club'},
#      {'id': '5YNnmXnEEEJM0ArqHDSyET', 'name': 'Lonely Benson'}],
#     'id': '4ertsRlco2bn3dWqY41sxS',
#     'name': 'Fantasy'}},
#   {'track': {'album': {'id': '6tlATjYhVr3LhLZGBjtQmB', 'name': 'Ovina'},
#     'artists': [{'id': '14xurMk6IfCAqEzI1txycG', 'name': 'Prinz Leo'},
#      {'id': '6VRAgC9krW0Ewz16KmTvZK', 'name': 'THAT KINDA VIBE'}],
#     'id': '0fO196iK1nt9tdoOLsn1pq',
#     'name': 'Ovina'}},
#   {'track': {'album': {'id': '3y6vDJUUxKT9zZ1veqouMp',
#      'name': 'Cosmic Sunrise'},
#     'artists': [{'id': '6asrIoUCBS9LTWl26Bo0fT', 'name': 'Carter Fox'},
#      {'id': '005IIda5UkmCXokco7snZg', 'name': 'Steve Honz'}],
#     'id': '7B0TvH0YA2nHfoccgRRTq1',
#     'name': 'Cosmic Sunrise'}},
#   {'track': {'album': {'id': '0iCRip4xkOrwKejPxO13s0', 'name': 'Elevenses'},
#     'artists': [{'id': '32lJwqZ7Tf3hp6oYnr9hSh', 'name': 'Second Breakfast'}],
#     'id': '41PfG9u4RTTyMXMw4T9x7T',
#     'name': 'beaming light'}},
#   {'track': {'album': {'id': '2i5wQo2Lp1t1fZZj225vBH', 'name': 'voiceless'},
#     'artists': [{'id': '6gQzBYh1naIayoJA567ATQ', 'name': 'Criibaby'},
#      {'id': '0xbNWCGKRUJ5wILr2dvQEO', 'name': 'Surfer Dave'}],
#     'id': '61qrps9b5q9THQEjIw9J64',
#     'name': 'home'}},
#   {'track': {'album': {'id': '7fgzEkEfuOQ8O12sjk275l',
#      'name': 'The Hi-Lofi Chronicles, Vol. 1'},
#     'artists': [{'id': '4W2Wr4txFhXLLGEXGwBa3J', 'name': 'Zero-B1'}],
#     'id': '5gxZyok3wk3IPyDIIuPKKB',
#     'name': 'Everything Bliss'}},
#   {'track': {'album': {'id': '2tZmQ6IBCmSWKlvkpGh0Ph',
#      'name': 'springtime lonely'},
#     'artists': [{'id': '2P08fd6pngLcSXUAGpsJSz', 'name': 'Boy Illum'}],
#     'id': '598YdJ5dReNQn3GYDdhnY9',
#     'name': 'springtime lonely'}},
#   {'track': {'album': {'id': '6APc76iPQ69N4dKAceKkMn', 'name': 'Red Sky'},
#     'artists': [{'id': '1z1vBZzW0Id2qR0FrFr5Yg', 'name': 'Sbeady'}],
#     'id': '135qlCw4Xds13ElAIVgDGf',
#     'name': 'Red Sky'}},
#   {'track': {'album': {'id': '4sy9xkgUrclVbLqqVXslrq', 'name': 'Wind Shear'},
#     'artists': [{'id': '2RBJhPBOr8mI5evwaL4HR3', 'name': 'Ghostnaut'},
#      {'id': '773SnwBYAvo9JlHuulUvMu', 'name': 'Lunath'},
#      {'id': '1K18BNpoYTlf251GQL1Mdz', 'name': 'Fayelo'}],
#     'id': '33xRLRHq485anywUECESNa',
#     'name': 'Wind Shear'}},
#   {'track': {'album': {'id': '5bIedzyuEIiSq9d5c6ViL8',
#      'name': 'Lost and Found'},
#     'artists': [{'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'},
#      {'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'}],
#     'id': '04oOc4suMWmpHSJ6b6GvJE',
#     'name': 'Lost and Found'}},
#   {'track': {'album': {'id': '0iFHakdcXdrqhVBOk69tkp', 'name': 'Mojito'},
#     'artists': [{'id': '0wOfP27EddIPwwB7X7ZrWP', 'name': 'Wataru Fujiwara'}],
#     'id': '7DDlCk1cqpE8xjvo1CEsrW',
#     'name': 'Mojito'}},
#   {'track': {'album': {'id': '2IaiUiW0RQgh8efceNlNXH',
#      'name': "Diggin' Deeper"},
#     'artists': [{'id': '7KH5fBS44kdTebdgzspYtJ',
#       'name': 'The Jazzual Suspects'}],
#     'id': '3ZiObkFOBSlRFKiH3MDp0o',
#     'name': 'Ninkasi'}},
#   {'track': {'album': {'id': '3d70ikFed9Wcm0Fa3oc0OP', 'name': 'fresco'},
#     'artists': [{'id': '15fMojo8Cll6nbSpkxSUJ9', 'name': 'lov lofi'}],
#     'id': '2AKkPcjrOppuzsLTr1zi9d',
#     'name': 'fresco'}},
#   {'track': {'album': {'id': '3Mlcc8Gq9wa7RNUFIxM8be', 'name': 'Lullaby Town'},
#     'artists': [{'id': '7LdE7z3rYGOa0R4u6Ev7aG', 'name': 'Rinse Cycle'}],
#     'id': '6PjYlS9kHwASAeioIlUoCM',
#     'name': 'Lullaby Town'}},
#   {'track': {'album': {'id': '7u0QglvjudYjBt2VVqAovV',
#      'name': 'Unhurried Nights'},
#     'artists': [{'id': '1z1vBZzW0Id2qR0FrFr5Yg', 'name': 'Sbeady'}],
#     'id': '4igSA8AlcSEnWnXhplgIY3',
#     'name': 'Unhurried Nights'}},
#   {'track': {'album': {'id': '7jhSffSt2fFINIZrNs7aAw', 'name': 'missing us'},
#     'artists': [{'id': '5408YTsXEeDoU6JMfu6S1p', 'name': 'Valera'},
#      {'id': '6rEjEIfp3NSRteU3kJGSET', 'name': '静的 Static'}],
#     'id': '1z7pHc4ujzaZn4QvLvOTu2',
#     'name': 'missing us'}},
#   {'track': {'album': {'id': '1Wa1aQWILfcLS6yLX11FCh', 'name': 'caffeine'},
#     'artists': [{'id': '7MZx3uoMDM7wE8An0kdHwa', 'name': 'Nosmoh'}],
#     'id': '5wTEYjQsWsWPIggseoxLLy',
#     'name': 'caffeine'}},
#   {'track': {'album': {'id': '1mGqrsoDizJtFDhwpSs7Vi', 'name': 'On My Way'},
#     'artists': [{'id': '1qc48l4N7tBU8sMOuIAa82', 'name': 'RINZ.'}],
#     'id': '0xr8vqzuCvfOWQvkl2b0T4',
#     'name': 'On My Way'}},
#   {'track': {'album': {'id': '43fBqtdIMOAG6eLldeL98H',
#      'name': 'Shot In The Dark'},
#     'artists': [{'id': '5Y2wHchGaDlDsk9FPC0YSE', 'name': 'Kid Kio'},
#      {'id': '40gnIR7KWV2R1MzHElf2oZ', 'name': 'Bad Room Producer'}],
#     'id': '1KuZbkU3I9mMMlgg8Iungr',
#     'name': 'Shot In The Dark'}},
#   {'track': {'album': {'id': '35by2kkpVvsxVZ7PLhP5W5', 'name': 'Traumwelt'},
#     'artists': [{'id': '0lh5lzZRrNVqtpfPTIkw2y',
#       'name': 'Vincent Krennerich'}],
#     'id': '5TpzDIcKhCTSoPAZauTxVF',
#     'name': 'Traumwelt'}},
#   {'track': {'album': {'id': '6YcDJzowxxwkosmeMrZy5V', 'name': 'Roll Out'},
#     'artists': [{'id': '4FRUdOCdgipvj69Ldv6kVQ', 'name': "The Rollin' Deep"}],
#     'id': '2McviRXRpd2PBWgev8YjYT',
#     'name': 'Roll Out'}},
#   {'track': {'album': {'id': '2uXsJE2vNPyfLtGwNcYC7Z',
#      'name': "Journey's End"},
#     'artists': [{'id': '2OOTNVKel4Dl6bdGfkChIx', 'name': 'Fireflyx'},
#      {'id': '5tZTqwfxy4zLaEWkVejTws', 'name': 'Angie Nicole'}],
#     'id': '3lgDki8dY1M0vKfOUtZKzA',
#     'name': "Journey's End"}},
#   {'track': {'album': {'id': '4Tc2Zt97fyB2j8jHcMXzv9', 'name': 'baltic'},
#     'artists': [{'id': '3bfbfASXy9KkodwZ28ykzM', 'name': 'paule'}],
#     'id': '5cqSb8cbJYYrHK8QsOPkOy',
#     'name': 'käsmu'}},
#   {'track': {'album': {'id': '4BQSUpeKpiaLhbf8C3oe1H',
#      'name': 'Coffee And Pie, Oh My!'},
#     'artists': [{'id': '5vjsK1KRuMhzdFJHYI8ll5', 'name': 'Trainsleeper'}],
#     'id': '1RKHfYrGwQVGld7XO2lOSt',
#     'name': 'Coffee And Pie, Oh My!'}},
#   {'track': {'album': {'id': '79B9hO4LHNoEWb9xlckv8M', 'name': 'Bloom'},
#     'artists': [{'id': '40GMyQ5sv1bfiui9CrEPME', 'name': 'Lawrence Walther'},
#      {'id': '4WfXJIC30dh3ezNzAmVi3m', 'name': 'Mantrick'},
#      {'id': '5Y2wHchGaDlDsk9FPC0YSE', 'name': 'Kid Kio'}],
#     'id': '69WwrZmqx941Xk3WU9PDRm',
#     'name': 'Bloom'}},
#   {'track': {'album': {'id': '5XH79jYq86rdDZrYhDdcWs',
#      'name': 'Under The Stars'},
#     'artists': [{'id': '2zNmlxTlRfyMAAifd2f71Q', 'name': 'amies'},
#      {'id': '1pCEnT5PUnUjcdIU0v1LZX', 'name': 'b.wub'}],
#     'id': '1UABIbOzJJYz9c1y8l1Rk4',
#     'name': 'Under The Stars'}},
#   {'track': {'album': {'id': '2j6wQ7lao8YHDIaoYUuqQN', 'name': 'Fly Away'},
#     'artists': [{'id': '4OiOGOoUj1rFh8WmSREZey', 'name': 'ilaywho'}],
#     'id': '3gsq3RsTrIi2pvfiVCSRGA',
#     'name': 'Fly Away'}},
#   {'track': {'album': {'id': '7HILhfhjOpTTtyYXMl5tqf', 'name': 'Calm Down'},
#     'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'}],
#     'id': '5KhoMiyDDs4vQazM6eE7jA',
#     'name': 'Calm Down'}},
#   {'track': {'album': {'id': '3eR9LSaYgw3ECOnBOU9Brn', 'name': 'halcyon'},
#     'artists': [{'id': '2RTHRVmtTiMDjDCZIOO9wq', 'name': 'sftspkn'}],
#     'id': '7oF48btFPoJRoCmrvG21zK',
#     'name': 'halcyon'}},
#   {'track': {'album': {'id': '5bIedzyuEIiSq9d5c6ViL8',
#      'name': 'Lost and Found'},
#     'artists': [{'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'},
#      {'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'}],
#     'id': '6sq9ljZwbSwYuo2EIP51fN',
#     'name': 'Solitude'}},
#   {'track': {'album': {'id': '1iC7XP3EJD0yGkk6rY4PLR',
#      'name': 'Life of Leisure'},
#     'artists': [{'id': '5qjAPKuzIah22bWJjDpS7s', 'name': 'Luettje Tuffels'}],
#     'id': '39Ae8yMKEEDOCGbCBuunDS',
#     'name': 'Life of Leisure'}},
#   {'track': {'album': {'id': '2nZAMDS4D0pnSRr73vniCn',
#      'name': 'Sailing Again'},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#      {'id': '68Re4wugc13HVak1p8Zawl', 'name': 'Yestalgia'}],
#     'id': '1MKt41aRnc3WPsgBsDnsJw',
#     'name': 'Sailing Again'}},
#   {'track': {'album': {'id': '4cGVrvrkWriQpXdaIIkniF', 'name': 'Blueberries'},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#      {'id': '5oYQJceaUGHcz6d7TGry4q', 'name': 'luv pug'}],
#     'id': '3X3ocbVSCGWGHRrzoAgfZD',
#     'name': 'Blueberries'}},
#   {'track': {'album': {'id': '3QVgInkMIbp6j2GRzXY079',
#      'name': 'When The Past Turned Present'},
#     'artists': [{'id': '7GsvnIE0bUBu6WZXO3ryJe', 'name': 'Sebastian Kamae'},
#      {'id': '0Eoy1XlOfZ0xiHKayBoJbi', 'name': 'Intoku'}],
#     'id': '1edWMkGVJw202hX8O2qJj9',
#     'name': 'When The Past Turned Present'}},
#   {'track': {'album': {'id': '3bftuH2u53z3M0wfr3KaM6', 'name': 'Passengers'},
#     'artists': [{'id': '5UL219t4aptfSBcRGFeLJU', 'name': 'Amaez'}],
#     'id': '5kIomUq2KEtCTLkXgx44wh',
#     'name': 'Passengers'}},
#   {'track': {'album': {'id': '5bIedzyuEIiSq9d5c6ViL8',
#      'name': 'Lost and Found'},
#     'artists': [{'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'},
#      {'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'}],
#     'id': '4Hy34rwCOmpa36MiHEsHFV',
#     'name': 'Sidewalking'}},
#   {'track': {'album': {'id': '1uMLXLtJYpdaWVv6gGB7XJ',
#      'name': 'Dreaming Of You'},
#     'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#     'id': '7JqAA1tdoL2cJpbDspMQjK',
#     'name': 'Dreaming Of You'}},
#   {'track': {'album': {'id': '20EaIYCQQURNxtsVoZBkZq', 'name': 'Loose Lines'},
#     'artists': [{'id': '6IUKOT5oMnQ8ZUyJlZFxO2', 'name': 'S I M'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '2JEWzzjqKj0yIeIUevC0rE',
#     'name': 'Loose Lines'}},
#   {'track': {'album': {'id': '57zUZY5y5NmjgJrZzrVLGV', 'name': 'Someday'},
#     'artists': [{'id': '2dGFrQsjmTaLK8o8aNuAeG', 'name': 'Kicktracks'}],
#     'id': '6vecjPIVtqgJniCqqHyATg',
#     'name': 'Darling'}},
#   {'track': {'album': {'id': '5nVj1ZqpPtYhN3vriVz4OG',
#      'name': 'New Day & Cherry'},
#     'artists': [{'id': '5r4pQdeOkSMx1y2NNMDSlu', 'name': 'Devon Rea'},
#      {'id': '3b0TLzX6FkeQvv9daBtFBe', 'name': 'Goson'}],
#     'id': '2qT0WX3CvFVpG3cUQps2cy',
#     'name': 'New Day'}},
#   {'track': {'album': {'id': '765Itge0zLTWCqL0yFjUCS', 'name': 'Waves'},
#     'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#     'id': '4vjLw4yt3CHgzqkUY4PF9u',
#     'name': 'Waves'}},
#   {'track': {'album': {'id': '1zrNXYrLhmQXUVT1oDnqPX', 'name': 'first love'},
#     'artists': [{'id': '0mOeV01tlL7BQheKuD05LX', 'name': 'sweet palm'}],
#     'id': '30P5l9ftm4qtWQfTS6op2r',
#     'name': 'first love'}},
#   {'track': {'album': {'id': '1ygecBXoEnr62WfbrhnKXX', 'name': 'Odyssey'},
#     'artists': [{'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'},
#      {'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'}],
#     'id': '4uy66poHcBJA80GbKFGpam',
#     'name': 'Purple Moon'}},
#   {'track': {'album': {'id': '4lKWekmYlSC9jzXqjdEcQf',
#      'name': 'air like perfume.'},
#     'artists': [{'id': '7r3gH36F9O5GtmYPYymtLK', 'name': 'coldbrew'}],
#     'id': '4nZY3o9EU0eOPTcjrbpkUt',
#     'name': 'air like perfume.'}},
#   {'track': {'album': {'id': '7cgUFRiQ822Nrfp4m10kOY', 'name': 'Azure'},
#     'artists': [{'id': '6DXpU6Gd2sctp0s2ryVNZA', 'name': 'Ellr'}],
#     'id': '5KNfKf13W6aVa3IGwWpkbN',
#     'name': 'Azure'}},
#   {'track': {'album': {'id': '5pfeNu6aJ2Y4Avt8hLdNby', 'name': 'Shoreline'},
#     'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#     'id': '248SKbigC5WrVxTZky8j3Q',
#     'name': 'Shoreline'}},
#   {'track': {'album': {'id': '492mx0k6jtTTwGkW0LCLXW', 'name': 'Express'},
#     'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'},
#      {'id': '52kTvSXed7Y3NB4X6MyXGf', 'name': 'Idepen'}],
#     'id': '26g7pUu82QepJJUR10RvBi',
#     'name': 'Express'}},
#   {'track': {'album': {'id': '4ARNxx6DDAqZ3LQ8OGkIEI', 'name': 'Flight 404'},
#     'artists': [{'id': '1BCaWmZ5a7IMTP5EFSPkfL', 'name': 'droemsk'},
#      {'id': '04zvEg1lhzzyN1rLgfO8hG', 'name': 'S-Ilo'},
#      {'id': '0L1eY5MVRiGxxfMa77yy3n', 'name': 'Jokujekku'}],
#     'id': '0iBydMPc0C7gL0B4XuEScG',
#     'name': 'Flight 404'}},
#   {'track': {'album': {'id': '10yRtUGfZxV8RjJm7jMcZO', 'name': 'The Mill'},
#     'artists': [{'id': '1K18BNpoYTlf251GQL1Mdz', 'name': 'Fayelo'}],
#     'id': '0hlyeFUF0LsDOj8PV0E2Vf',
#     'name': 'The Mill'}},
#   {'track': {'album': {'id': '0lGEG3nS1xtAGTb98IS0bv', 'name': 'Night Echo'},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#      {'id': '3iGthn6RykA9JUHnilAIr0', 'name': 'Krynoze'}],
#     'id': '2FxmhQR0dQ3AbcY5zoBcnx',
#     'name': 'Night Echo'}},
#   {'track': {'album': {'id': '2HyoJhve44OmS3NE318eTu', 'name': 'Driftwood'},
#     'artists': [{'id': '7LdE7z3rYGOa0R4u6Ev7aG', 'name': 'Rinse Cycle'}],
#     'id': '1KcTcmiTkDRvCvSgx5j5Ba',
#     'name': 'Driftwood'}},
#   {'track': {'album': {'id': '4db3lAOSr8yk43RyX03pLk', 'name': 'Breathe In'},
#     'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#     'id': '3J8Ed5DcqfbPhf5cIlTZBU',
#     'name': 'Breathe In'}},
#   {'track': {'album': {'id': '1XpjOJgeUEt4UjMb1l7dEv', 'name': 'Marigold'},
#     'artists': [{'id': '0PbBgZYFayICVW0646NtXG', 'name': 'CMJ'}],
#     'id': '6o5JrW8DAmO6lFjfG3lirq',
#     'name': 'Marigold'}},
#   {'track': {'album': {'id': '5e4vR0uAxpgz7Dj0fITEyU', 'name': 'Folia'},
#     'artists': [{'id': '14xurMk6IfCAqEzI1txycG', 'name': 'Prinz Leo'},
#      {'id': '6VRAgC9krW0Ewz16KmTvZK', 'name': 'THAT KINDA VIBE'}],
#     'id': '00a5ijjVYSdEOEAmTTmTKG',
#     'name': 'Folia'}},
#   {'track': {'album': {'id': '7IROlKvDqqdlTkhZNRuVrk',
#      'name': 'For Tonight & Hopeful'},
#     'artists': [{'id': '5r4pQdeOkSMx1y2NNMDSlu', 'name': 'Devon Rea'},
#      {'id': '3b0TLzX6FkeQvv9daBtFBe', 'name': 'Goson'}],
#     'id': '4Ca6yyUJpcHujHGSvKPprg',
#     'name': 'For Tonight'}},
#   {'track': {'album': {'id': '1BEjv2GVteeJU5YKMcAtX1',
#      'name': 'Sunny Morning'},
#     'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#     'id': '16xkAXuFcdEd5VUHbDAMr6',
#     'name': 'Sunny Morning'}},
#   {'track': {'album': {'id': '17q6t75PVw0LcBAtZvWS00', 'name': 'Brightening'},
#     'artists': [{'id': '2SJLGPoAJhy9Id6N8oAftk', 'name': 'Juliàn'},
#      {'id': '3iGthn6RykA9JUHnilAIr0', 'name': 'Krynoze'}],
#     'id': '3SHMV8tJrcZGiMOgAt48F8',
#     'name': 'Brightening'}},
#   {'track': {'album': {'id': '4SiRQXdFEYRC0JZ6Gf32kH',
#      'name': 'Never The Same'},
#     'artists': [{'id': '7GsvnIE0bUBu6WZXO3ryJe', 'name': 'Sebastian Kamae'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '47EikapMb3zqYaFXkuz8Ub',
#     'name': 'Never The Same'}},
#   {'track': {'album': {'id': '3yFhvFNA9Wuc7f1Atpvb3X', 'name': 'Grandma'},
#     'artists': [{'id': '4KTl9YHavX4GehM7sDgHKr', 'name': 'JIrons'}],
#     'id': '6tdZyDiv9oQ8k8s4ezh6e8',
#     'name': 'Grandma'}},
#   {'track': {'album': {'id': '0woeCMmM7CpHgOmohOiASD', 'name': 'Looking Back'},
#     'artists': [{'id': '1ioPe940lafF8R9ejGRRpW', 'name': 'Enoki'}],
#     'id': '6XDaEkj49oZQ9ivXmsXVrZ',
#     'name': 'Looking Back'}},
#   {'track': {'album': {'id': '1ZiNxD3Mi0Sg6ORrtLxdZf', 'name': 'Seesaw'},
#     'artists': [{'id': '3oR6i8bFLe2JWAOWFEf7xz', 'name': 'DoublePercent'}],
#     'id': '7FEkxO6kVqFbUX9zm2XWhE',
#     'name': 'Seesaw'}},
#   {'track': {'album': {'id': '2PWowiMTiRnRFmLThlovgp', 'name': 'Sonder'},
#     'artists': [{'id': '4rgy5K4lHDLbaSC1MMuY5m', 'name': 'sinnr'},
#      {'id': '6CNlouXOE8j6UGHVmtagw6', 'name': 'Spinmont'}],
#     'id': '0e3Eh8wigW1HPYYt2SugTZ',
#     'name': 'Sonder'}},
#   {'track': {'album': {'id': '0rZW9igkkl9cl38eVeLDcR', 'name': 'Shining'},
#     'artists': [{'id': '2AneE7YpS3dgN9XjDgv2pO', 'name': 'Aoko'},
#      {'id': '4bkOWEgiKDhSsMCJGeAfxj', 'name': 'Jav Cast'}],
#     'id': '5nrR2VbzLIpdSbTniavPhW',
#     'name': 'Shining'}},
#   {'track': {'album': {'id': '5yX06p5aUvWDxMusXdHzO6', 'name': 'Morgen'},
#     'artists': [{'id': '0lh5lzZRrNVqtpfPTIkw2y',
#       'name': 'Vincent Krennerich'}],
#     'id': '3OU7FHDLRFoZh7anMwUCPA',
#     'name': 'Tiefblau'}},
#   {'track': {'album': {'id': '2BojgWgpcRgzOXd99HXui4', 'name': 'monterey'},
#     'artists': [{'id': '24PuTGiB6ISP3wErX3RzRT', 'name': 'CHASE STEPHEN'}],
#     'id': '5HZSnBCQKvfCRK96lUNt6V',
#     'name': 'monterey'}},
#   {'track': {'album': {'id': '3zqcBxINzRrMAHU3xJ5IwE', 'name': 'Up And Down'},
#     'artists': [{'id': '2SJLGPoAJhy9Id6N8oAftk', 'name': 'Juliàn'}],
#     'id': '6u4gvkwHQ8x8iLLSSGnHoZ',
#     'name': 'Up And Down'}},
#   {'track': {'album': {'id': '4jiywQHy2CDsMi32YJNphi', 'name': 'That Night'},
#     'artists': [{'id': '4CHVFfmgOpcOMB3d3B0uwO',
#       'name': 'Colours in Context'}],
#     'id': '6PP2oJo47Gxn7qAU9DWtHv',
#     'name': 'That Night'}},
#   {'track': {'album': {'id': '2fxoRdyO8G4dpco5eFBL71', 'name': 'Roadtrip'},
#     'artists': [{'id': '6UFQmSPDWaWReDLcCrPyNL', 'name': 'Early Garden'}],
#     'id': '4J99XW9Dca4hHhxslOaWwn',
#     'name': 'Roadtrip'}},
#   {'track': {'album': {'id': '3n9JHPdHK5j0P39q7xUAL9',
#      'name': 'birds out to play'},
#     'artists': [{'id': '7r3gH36F9O5GtmYPYymtLK', 'name': 'coldbrew'}],
#     'id': '0OXjb6VGGkenGDhAmJiXGc',
#     'name': 'birds out to play'}},
#   {'track': {'album': {'id': '3OSRCYmqTlckMPzt45L4kq', 'name': 'Tall'},
#     'artists': [{'id': '4OiOGOoUj1rFh8WmSREZey', 'name': 'ilaywho'}],
#     'id': '1kFNm3Y3Ry2veWoK6BDR1z',
#     'name': 'Tall'}},
#   {'track': {'album': {'id': '4MPHiV7la9yZ3Ybu26eaVd',
#      'name': 'freshflips 052021'},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#      {'id': '38PTbKsLfXgSDIINnVBl8P', 'name': 'freshgoodies'}],
#     'id': '7d0jg10Wnb8dPdwPJgGnok',
#     'name': 'Spring Garden'}},
#   {'track': {'album': {'id': '4PLWYO8FjMSeWxYCLcpuNP',
#      'name': 'Dreams and Schemes'},
#     'artists': [{'id': '5Srat14VYy1jsG2vupuogv', 'name': 'David Tam'}],
#     'id': '3pSIxhrRjUAbtLEOfteDD0',
#     'name': 'Dreams and Schemes'}},
#   {'track': {'album': {'id': '1aJ062Scvz8QmdLlniLYML', 'name': 'Youth'},
#     'artists': [{'id': '4CHVFfmgOpcOMB3d3B0uwO', 'name': 'Colours in Context'},
#      {'id': '0iMWUBpWAGKAenBVePrZFP', 'name': 'Project AER'}],
#     'id': '4YA50O4gAlyeFr0CCBGFQ7',
#     'name': 'Youth'}},
#   {'track': {'album': {'id': '1KEi6Rff0xWN8f8PCdsHG8',
#      'name': 'a new beginning'},
#     'artists': [{'id': '7r3gH36F9O5GtmYPYymtLK', 'name': 'coldbrew'}],
#     'id': '6W6hjFe18mtTOEyc8GEJa7',
#     'name': 'a new beginning'}},
#   {'track': {'album': {'id': '7yrlqNul7x8jz2OT90Ooc8', 'name': 'Gentle Night'},
#     'artists': [{'id': '5jZeLexrrwGNUy6nv7tzdr', 'name': 'C4C'}],
#     'id': '2sJWWuWGTlxcMf3HDyCBzq',
#     'name': 'Gentle Night'}},
#   {'track': {'album': {'id': '2MrXOablHUwYzuW7Xs8xce',
#      'name': "Slip 'n Slide"},
#     'artists': [{'id': '68XfjORA2datUxlEUBwQQV', 'name': 'Anne Drew'},
#      {'id': '39lo8UU0LRMGTcHzmqMK9p', 'name': 'SunShun'}],
#     'id': '425gOBuquldfSIarKq4tzT',
#     'name': "Slip 'n Slide"}},
#   {'track': {'album': {'id': '5xDzCVfd8jfcH4qo3fsuQ5', 'name': 'Moonlight'},
#     'artists': [{'id': '3oR6i8bFLe2JWAOWFEf7xz', 'name': 'DoublePercent'}],
#     'id': '3WTrGUed4Ni2Fg3P5bWeco',
#     'name': 'Moonlight'}},
#   {'track': {'album': {'id': '6HPQfXJo8OFpyMxGjdIqbm', 'name': 'New Moon'},
#     'artists': [{'id': '59HCGLavl7XxBSiAdB2L8j', 'name': 'Hz.'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '2ZbvON6YdaYgcO1PiIA4uw',
#     'name': 'New Moon'}},
#   {'track': {'album': {'id': '3L6FN8rlrHaEf5AcM6DIR6',
#      'name': 'Serenity 2021'},
#     'artists': [{'id': '3vAvHFXAMYvfj5AO2CoYyX', 'name': 'Funcc.'},
#      {'id': '47OYz3d3DvnXpfaJ7i0z6b', 'name': 'Epifania'}],
#     'id': '4lYM3Ddwnz6vHQIVxtPAEk',
#     'name': 'Serendipity'}},
#   {'track': {'album': {'id': '0P7SIlPSll7dT2yOTZf0ej', 'name': 'Noodle House'},
#     'artists': [{'id': '61ZwgexUIZqT7ymSPsCW0H', 'name': 'Vannorte'}],
#     'id': '0IleR2MBZWzTYlLOW02jxZ',
#     'name': 'Noodle House'}},
#   {'track': {'album': {'id': '5vgHWGJaa3CgiZuw0x2WRi', 'name': 'Samurai'},
#     'artists': [{'id': '0BiIN25nWNSub42oUnFKoM', 'name': 'VINCENT MOON'},
#      {'id': '7j8hJ3AUvRVQp2J4eFxjVi', 'name': 'Farnell Newton'}],
#     'id': '3Rb52ZLcNvASaoprWY3KKA',
#     'name': 'Samurai'}},
#   {'track': {'album': {'id': '7uNrB3L5VZcMNOPXGaqnpa',
#      'name': 'Cabin Daydreams'},
#     'artists': [{'id': '7LdE7z3rYGOa0R4u6Ev7aG', 'name': 'Rinse Cycle'},
#      {'id': '6MvnyPinXRQbUCMsPoymhR', 'name': 'Lenny Loops'}],
#     'id': '2eBYHEV8IEfPsCYTxqpU0w',
#     'name': 'Cabin Daydreams'}},
#   {'track': {'album': {'id': '2IAM3OhY6Rfl1qeLrWJL4I',
#      'name': 'everything we had'},
#     'artists': [{'id': '4rAXFOfQ4Q5hwOF492tEuI', 'name': 'Vikram Dhakal'},
#      {'id': '6L9h5cN2DNOoMqFRgIv7uU', 'name': 'Banks'}],
#     'id': '2wRjgsdGXKMB7UdyhrFq8k',
#     'name': 'everything we had'}},
#   {'track': {'album': {'id': '79LnQ7KghS4P2SaSuGVkRt', 'name': 'Winter White'},
#     'artists': [{'id': '7nT0BfoHBOjL5yGLTRLmhm', 'name': 'CrazyJaZz'},
#      {'id': '5n9SautEmQzoC7G47NBta0', 'name': '.Eehou'},
#      {'id': '1YreDOGr8en691i5jQJJMK', 'name': 'Otis Ubaka'}],
#     'id': '0s3upcb2FRkUdAoeJwTqqO',
#     'name': 'Winter White'}},
#   {'track': {'album': {'id': '2K0M2K3cOIfXWEpVD8CcVA', 'name': 'Care Package'},
#     'artists': [{'id': '69NXAR2kpX8fv5ed7xJpgx', 'name': 'Maadrhino'},
#      {'id': '723wJl33DPwM2dF6n0rxaZ', 'name': 'Musqitone'}],
#     'id': '4Of7SxCmZXs7TtM9Qlwie6',
#     'name': 'Milk Tooth'}},
#   {'track': {'album': {'id': '7zsXXquownEgLT97g3ZYMk', 'name': 'winterglow'},
#     'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '0pjir6f0ROoeKVFsULDrAN',
#     'name': 'winterglow'}},
#   {'track': {'album': {'id': '4PCowd1WuaguRhdqZXbJ3R', 'name': 'equinox'},
#     'artists': [{'id': '4ApyJoQGYHAcMtJEvK5tRx', 'name': 'steezy prime'},
#      {'id': '0iMWUBpWAGKAenBVePrZFP', 'name': 'Project AER'}],
#     'id': '3vb60Ds1X9nnIgcmDedDeX',
#     'name': 'equinox'}},
#   {'track': {'album': {'id': '1MEl08VubrmP6PFQWEB0q3',
#      'name': 'forest lullaby'},
#     'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'},
#      {'id': '4bkOWEgiKDhSsMCJGeAfxj', 'name': 'Jav Cast'}],
#     'id': '7zc2FDuqxw5ooCAuTxhuYd',
#     'name': 'forest lullaby'}},
#   {'track': {'album': {'id': '40137huzteS9vC4gGX2UP8', 'name': 'La Paz Tape'},
#     'artists': [{'id': '7gVcXipsVVlTpZ8mMjzsJL', 'name': 'SP kOwi'},
#      {'id': '3WEutW4SLc7V9PiKTDM7bD', 'name': 'Bobby Dreamz BIG'}],
#     'id': '1Iu8iywvfaqrhE48hA9gzm',
#     'name': 'Miraflores'}},
#   {'track': {'album': {'id': '2ue91iJeMU7Cmo5G62qFNo', 'name': 'no vacancy'},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '7BeR8KNgFQH30dZNVpZvJm',
#     'name': 'no vacancy'}},
#   {'track': {'album': {'id': '7JN5Ho0LxQwXkaP4Q9PgBk',
#      'name': 'Mellow Mornings'},
#     'artists': [{'id': '36L95dDAJG3EJ2tstIZpFj', 'name': 'Mr. Jello'},
#      {'id': '7j8hJ3AUvRVQp2J4eFxjVi', 'name': 'Farnell Newton'}],
#     'id': '3UiC8AF5jVDqAifEcQ2oDC',
#     'name': 'Mellow Mornings'}},
#   {'track': {'album': {'id': '3bP8E51JPSFQiZynfgBH7x', 'name': 'Snow Walk'},
#     'artists': [{'id': '6TsSBSisvQYCupsHmXe1iK', 'name': 'URCHN'},
#      {'id': '68XfjORA2datUxlEUBwQQV', 'name': 'Anne Drew'}],
#     'id': '3xzNluHOcDeu6AoR5gC3wJ',
#     'name': 'Snow Walk'}},
#   {'track': {'album': {'id': '4uuDHcmeaCTR8BmIVl15Hs', 'name': 'Nourish'},
#     'artists': [{'id': '68Re4wugc13HVak1p8Zawl', 'name': 'Yestalgia'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '1AtPzw458O0tAWDh5ch6Sj',
#     'name': 'Nourish'}},
#   {'track': {'album': {'id': '5YFzITz3FPAm7V3a2tTeI5', 'name': 'Bubba'},
#     'artists': [{'id': '7oc0u9Q0BkLat7c10fuHoF', 'name': 'Jr. Wellness'}],
#     'id': '30Ak0wMBgFEphMwMDQdY5t',
#     'name': 'Bubba'}},
#   {'track': {'album': {'id': '6rBnuL3apGfI42RaL9MJix',
#      'name': "you're not lost"},
#     'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#      {'id': '59HCGLavl7XxBSiAdB2L8j', 'name': 'Hz.'}],
#     'id': '0NIawAn7SZDA1CQ1G8GybR',
#     'name': "you're not lost"}},
#   {'track': {'album': {'id': '0evwpdvENzJNsIh0HdvDRB', 'name': 'Pulcro'},
#     'artists': [{'id': '15fMojo8Cll6nbSpkxSUJ9', 'name': 'lov lofi'}],
#     'id': '17G7wk2KmRyaqCeRBLMFqI',
#     'name': 'Pulcro'}},
#   {'track': {'album': {'id': '2ObFvn0oxuZGAkc4kBbaU2', 'name': 'Below Zero'},
#     'artists': [{'id': '2tqQ33SdGO1LqNg8DQDCio', 'name': 'SamuW'},
#      {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#     'id': '3dUNxiEf72V2en2nC9GOut',
#     'name': 'Below Zero'}}],
#  'next': 'https://api.spotify.com/v1/playlists/1qvW13XhfMMZMlzQx362HR/tracks?offset=100&limit=100&fields=next,items(track(artists(id,name),album(id,name),id,name))'}

# %%
items = r_json["items"]
next = r_json["next"]

# %% [markdown]
# Spotify returns only 100 tracks per request

# %%
print(len(items))
print(next)
# Out:
# 100
# https://api.spotify.com/v1/playlists/1qvW13XhfMMZMlzQx362HR/tracks?offset=100&limit=100&fields=next,items(track(artists(id,name),album(id,name),id,name))

# %% [markdown]
# Again we need to account for pagination.

# %%
all_items = items

r = requests.get(url=next, headers=headers)
r_json = r.json()
items = r_json["items"]
next = r_json["next"]

all_items = all_items + items
all_items
# Out:
# [{'track': {'album': {'id': '0c6GZXLOQNRRfoJSCraLwc', 'name': 'Pendulum'},
#    'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '5XfGPtiNkoPkeK00QTEHCb',
#    'name': 'Pendulum'}},
#  {'track': {'album': {'id': '3W1TKjeKQawzmVlBGr9eOr', 'name': 'Cheer Up'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '0CVT6rpAdkDm4NKLdv7E9g',
#    'name': 'Cheer Up'}},
#  {'track': {'album': {'id': '04YdOVml7kXJN985zOOHPX', 'name': 'Endless Road'},
#    'artists': [{'id': '2RBJhPBOr8mI5evwaL4HR3', 'name': 'Ghostnaut'},
#     {'id': '1XFN3VcuKr4tsTtQlRiTgK', 'name': 'Mondo Loops'},
#     {'id': '773SnwBYAvo9JlHuulUvMu', 'name': 'Lunath'}],
#    'id': '1Kqx9kj7twQEexWCa4WHUZ',
#    'name': 'Endless Road'}},
#  {'track': {'album': {'id': '4WjETwIOQcthrTokTKIOvL', 'name': 'II'},
#    'artists': [{'id': '6CzaYsf8RIrCHNDhFGSfgm', 'name': 'Havana Swim Club'},
#     {'id': '5YNnmXnEEEJM0ArqHDSyET', 'name': 'Lonely Benson'}],
#    'id': '4ertsRlco2bn3dWqY41sxS',
#    'name': 'Fantasy'}},
#  {'track': {'album': {'id': '6tlATjYhVr3LhLZGBjtQmB', 'name': 'Ovina'},
#    'artists': [{'id': '14xurMk6IfCAqEzI1txycG', 'name': 'Prinz Leo'},
#     {'id': '6VRAgC9krW0Ewz16KmTvZK', 'name': 'THAT KINDA VIBE'}],
#    'id': '0fO196iK1nt9tdoOLsn1pq',
#    'name': 'Ovina'}},
#  {'track': {'album': {'id': '3y6vDJUUxKT9zZ1veqouMp',
#     'name': 'Cosmic Sunrise'},
#    'artists': [{'id': '6asrIoUCBS9LTWl26Bo0fT', 'name': 'Carter Fox'},
#     {'id': '005IIda5UkmCXokco7snZg', 'name': 'Steve Honz'}],
#    'id': '7B0TvH0YA2nHfoccgRRTq1',
#    'name': 'Cosmic Sunrise'}},
#  {'track': {'album': {'id': '0iCRip4xkOrwKejPxO13s0', 'name': 'Elevenses'},
#    'artists': [{'id': '32lJwqZ7Tf3hp6oYnr9hSh', 'name': 'Second Breakfast'}],
#    'id': '41PfG9u4RTTyMXMw4T9x7T',
#    'name': 'beaming light'}},
#  {'track': {'album': {'id': '2i5wQo2Lp1t1fZZj225vBH', 'name': 'voiceless'},
#    'artists': [{'id': '6gQzBYh1naIayoJA567ATQ', 'name': 'Criibaby'},
#     {'id': '0xbNWCGKRUJ5wILr2dvQEO', 'name': 'Surfer Dave'}],
#    'id': '61qrps9b5q9THQEjIw9J64',
#    'name': 'home'}},
#  {'track': {'album': {'id': '7fgzEkEfuOQ8O12sjk275l',
#     'name': 'The Hi-Lofi Chronicles, Vol. 1'},
#    'artists': [{'id': '4W2Wr4txFhXLLGEXGwBa3J', 'name': 'Zero-B1'}],
#    'id': '5gxZyok3wk3IPyDIIuPKKB',
#    'name': 'Everything Bliss'}},
#  {'track': {'album': {'id': '2tZmQ6IBCmSWKlvkpGh0Ph',
#     'name': 'springtime lonely'},
#    'artists': [{'id': '2P08fd6pngLcSXUAGpsJSz', 'name': 'Boy Illum'}],
#    'id': '598YdJ5dReNQn3GYDdhnY9',
#    'name': 'springtime lonely'}},
#  {'track': {'album': {'id': '6APc76iPQ69N4dKAceKkMn', 'name': 'Red Sky'},
#    'artists': [{'id': '1z1vBZzW0Id2qR0FrFr5Yg', 'name': 'Sbeady'}],
#    'id': '135qlCw4Xds13ElAIVgDGf',
#    'name': 'Red Sky'}},
#  {'track': {'album': {'id': '4sy9xkgUrclVbLqqVXslrq', 'name': 'Wind Shear'},
#    'artists': [{'id': '2RBJhPBOr8mI5evwaL4HR3', 'name': 'Ghostnaut'},
#     {'id': '773SnwBYAvo9JlHuulUvMu', 'name': 'Lunath'},
#     {'id': '1K18BNpoYTlf251GQL1Mdz', 'name': 'Fayelo'}],
#    'id': '33xRLRHq485anywUECESNa',
#    'name': 'Wind Shear'}},
#  {'track': {'album': {'id': '5bIedzyuEIiSq9d5c6ViL8',
#     'name': 'Lost and Found'},
#    'artists': [{'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'},
#     {'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'}],
#    'id': '04oOc4suMWmpHSJ6b6GvJE',
#    'name': 'Lost and Found'}},
#  {'track': {'album': {'id': '0iFHakdcXdrqhVBOk69tkp', 'name': 'Mojito'},
#    'artists': [{'id': '0wOfP27EddIPwwB7X7ZrWP', 'name': 'Wataru Fujiwara'}],
#    'id': '7DDlCk1cqpE8xjvo1CEsrW',
#    'name': 'Mojito'}},
#  {'track': {'album': {'id': '2IaiUiW0RQgh8efceNlNXH',
#     'name': "Diggin' Deeper"},
#    'artists': [{'id': '7KH5fBS44kdTebdgzspYtJ',
#      'name': 'The Jazzual Suspects'}],
#    'id': '3ZiObkFOBSlRFKiH3MDp0o',
#    'name': 'Ninkasi'}},
#  {'track': {'album': {'id': '3d70ikFed9Wcm0Fa3oc0OP', 'name': 'fresco'},
#    'artists': [{'id': '15fMojo8Cll6nbSpkxSUJ9', 'name': 'lov lofi'}],
#    'id': '2AKkPcjrOppuzsLTr1zi9d',
#    'name': 'fresco'}},
#  {'track': {'album': {'id': '3Mlcc8Gq9wa7RNUFIxM8be', 'name': 'Lullaby Town'},
#    'artists': [{'id': '7LdE7z3rYGOa0R4u6Ev7aG', 'name': 'Rinse Cycle'}],
#    'id': '6PjYlS9kHwASAeioIlUoCM',
#    'name': 'Lullaby Town'}},
#  {'track': {'album': {'id': '7u0QglvjudYjBt2VVqAovV',
#     'name': 'Unhurried Nights'},
#    'artists': [{'id': '1z1vBZzW0Id2qR0FrFr5Yg', 'name': 'Sbeady'}],
#    'id': '4igSA8AlcSEnWnXhplgIY3',
#    'name': 'Unhurried Nights'}},
#  {'track': {'album': {'id': '7jhSffSt2fFINIZrNs7aAw', 'name': 'missing us'},
#    'artists': [{'id': '5408YTsXEeDoU6JMfu6S1p', 'name': 'Valera'},
#     {'id': '6rEjEIfp3NSRteU3kJGSET', 'name': '静的 Static'}],
#    'id': '1z7pHc4ujzaZn4QvLvOTu2',
#    'name': 'missing us'}},
#  {'track': {'album': {'id': '1Wa1aQWILfcLS6yLX11FCh', 'name': 'caffeine'},
#    'artists': [{'id': '7MZx3uoMDM7wE8An0kdHwa', 'name': 'Nosmoh'}],
#    'id': '5wTEYjQsWsWPIggseoxLLy',
#    'name': 'caffeine'}},
#  {'track': {'album': {'id': '1mGqrsoDizJtFDhwpSs7Vi', 'name': 'On My Way'},
#    'artists': [{'id': '1qc48l4N7tBU8sMOuIAa82', 'name': 'RINZ.'}],
#    'id': '0xr8vqzuCvfOWQvkl2b0T4',
#    'name': 'On My Way'}},
#  {'track': {'album': {'id': '43fBqtdIMOAG6eLldeL98H',
#     'name': 'Shot In The Dark'},
#    'artists': [{'id': '5Y2wHchGaDlDsk9FPC0YSE', 'name': 'Kid Kio'},
#     {'id': '40gnIR7KWV2R1MzHElf2oZ', 'name': 'Bad Room Producer'}],
#    'id': '1KuZbkU3I9mMMlgg8Iungr',
#    'name': 'Shot In The Dark'}},
#  {'track': {'album': {'id': '35by2kkpVvsxVZ7PLhP5W5', 'name': 'Traumwelt'},
#    'artists': [{'id': '0lh5lzZRrNVqtpfPTIkw2y', 'name': 'Vincent Krennerich'}],
#    'id': '5TpzDIcKhCTSoPAZauTxVF',
#    'name': 'Traumwelt'}},
#  {'track': {'album': {'id': '6YcDJzowxxwkosmeMrZy5V', 'name': 'Roll Out'},
#    'artists': [{'id': '4FRUdOCdgipvj69Ldv6kVQ', 'name': "The Rollin' Deep"}],
#    'id': '2McviRXRpd2PBWgev8YjYT',
#    'name': 'Roll Out'}},
#  {'track': {'album': {'id': '2uXsJE2vNPyfLtGwNcYC7Z', 'name': "Journey's End"},
#    'artists': [{'id': '2OOTNVKel4Dl6bdGfkChIx', 'name': 'Fireflyx'},
#     {'id': '5tZTqwfxy4zLaEWkVejTws', 'name': 'Angie Nicole'}],
#    'id': '3lgDki8dY1M0vKfOUtZKzA',
#    'name': "Journey's End"}},
#  {'track': {'album': {'id': '4Tc2Zt97fyB2j8jHcMXzv9', 'name': 'baltic'},
#    'artists': [{'id': '3bfbfASXy9KkodwZ28ykzM', 'name': 'paule'}],
#    'id': '5cqSb8cbJYYrHK8QsOPkOy',
#    'name': 'käsmu'}},
#  {'track': {'album': {'id': '4BQSUpeKpiaLhbf8C3oe1H',
#     'name': 'Coffee And Pie, Oh My!'},
#    'artists': [{'id': '5vjsK1KRuMhzdFJHYI8ll5', 'name': 'Trainsleeper'}],
#    'id': '1RKHfYrGwQVGld7XO2lOSt',
#    'name': 'Coffee And Pie, Oh My!'}},
#  {'track': {'album': {'id': '79B9hO4LHNoEWb9xlckv8M', 'name': 'Bloom'},
#    'artists': [{'id': '40GMyQ5sv1bfiui9CrEPME', 'name': 'Lawrence Walther'},
#     {'id': '4WfXJIC30dh3ezNzAmVi3m', 'name': 'Mantrick'},
#     {'id': '5Y2wHchGaDlDsk9FPC0YSE', 'name': 'Kid Kio'}],
#    'id': '69WwrZmqx941Xk3WU9PDRm',
#    'name': 'Bloom'}},
#  {'track': {'album': {'id': '5XH79jYq86rdDZrYhDdcWs',
#     'name': 'Under The Stars'},
#    'artists': [{'id': '2zNmlxTlRfyMAAifd2f71Q', 'name': 'amies'},
#     {'id': '1pCEnT5PUnUjcdIU0v1LZX', 'name': 'b.wub'}],
#    'id': '1UABIbOzJJYz9c1y8l1Rk4',
#    'name': 'Under The Stars'}},
#  {'track': {'album': {'id': '2j6wQ7lao8YHDIaoYUuqQN', 'name': 'Fly Away'},
#    'artists': [{'id': '4OiOGOoUj1rFh8WmSREZey', 'name': 'ilaywho'}],
#    'id': '3gsq3RsTrIi2pvfiVCSRGA',
#    'name': 'Fly Away'}},
#  {'track': {'album': {'id': '7HILhfhjOpTTtyYXMl5tqf', 'name': 'Calm Down'},
#    'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'}],
#    'id': '5KhoMiyDDs4vQazM6eE7jA',
#    'name': 'Calm Down'}},
#  {'track': {'album': {'id': '3eR9LSaYgw3ECOnBOU9Brn', 'name': 'halcyon'},
#    'artists': [{'id': '2RTHRVmtTiMDjDCZIOO9wq', 'name': 'sftspkn'}],
#    'id': '7oF48btFPoJRoCmrvG21zK',
#    'name': 'halcyon'}},
#  {'track': {'album': {'id': '5bIedzyuEIiSq9d5c6ViL8',
#     'name': 'Lost and Found'},
#    'artists': [{'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'},
#     {'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'}],
#    'id': '6sq9ljZwbSwYuo2EIP51fN',
#    'name': 'Solitude'}},
#  {'track': {'album': {'id': '1iC7XP3EJD0yGkk6rY4PLR',
#     'name': 'Life of Leisure'},
#    'artists': [{'id': '5qjAPKuzIah22bWJjDpS7s', 'name': 'Luettje Tuffels'}],
#    'id': '39Ae8yMKEEDOCGbCBuunDS',
#    'name': 'Life of Leisure'}},
#  {'track': {'album': {'id': '2nZAMDS4D0pnSRr73vniCn', 'name': 'Sailing Again'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '68Re4wugc13HVak1p8Zawl', 'name': 'Yestalgia'}],
#    'id': '1MKt41aRnc3WPsgBsDnsJw',
#    'name': 'Sailing Again'}},
#  {'track': {'album': {'id': '4cGVrvrkWriQpXdaIIkniF', 'name': 'Blueberries'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '5oYQJceaUGHcz6d7TGry4q', 'name': 'luv pug'}],
#    'id': '3X3ocbVSCGWGHRrzoAgfZD',
#    'name': 'Blueberries'}},
#  {'track': {'album': {'id': '3QVgInkMIbp6j2GRzXY079',
#     'name': 'When The Past Turned Present'},
#    'artists': [{'id': '7GsvnIE0bUBu6WZXO3ryJe', 'name': 'Sebastian Kamae'},
#     {'id': '0Eoy1XlOfZ0xiHKayBoJbi', 'name': 'Intoku'}],
#    'id': '1edWMkGVJw202hX8O2qJj9',
#    'name': 'When The Past Turned Present'}},
#  {'track': {'album': {'id': '3bftuH2u53z3M0wfr3KaM6', 'name': 'Passengers'},
#    'artists': [{'id': '5UL219t4aptfSBcRGFeLJU', 'name': 'Amaez'}],
#    'id': '5kIomUq2KEtCTLkXgx44wh',
#    'name': 'Passengers'}},
#  {'track': {'album': {'id': '5bIedzyuEIiSq9d5c6ViL8',
#     'name': 'Lost and Found'},
#    'artists': [{'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'},
#     {'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'}],
#    'id': '4Hy34rwCOmpa36MiHEsHFV',
#    'name': 'Sidewalking'}},
#  {'track': {'album': {'id': '1uMLXLtJYpdaWVv6gGB7XJ',
#     'name': 'Dreaming Of You'},
#    'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#    'id': '7JqAA1tdoL2cJpbDspMQjK',
#    'name': 'Dreaming Of You'}},
#  {'track': {'album': {'id': '20EaIYCQQURNxtsVoZBkZq', 'name': 'Loose Lines'},
#    'artists': [{'id': '6IUKOT5oMnQ8ZUyJlZFxO2', 'name': 'S I M'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '2JEWzzjqKj0yIeIUevC0rE',
#    'name': 'Loose Lines'}},
#  {'track': {'album': {'id': '57zUZY5y5NmjgJrZzrVLGV', 'name': 'Someday'},
#    'artists': [{'id': '2dGFrQsjmTaLK8o8aNuAeG', 'name': 'Kicktracks'}],
#    'id': '6vecjPIVtqgJniCqqHyATg',
#    'name': 'Darling'}},
#  {'track': {'album': {'id': '5nVj1ZqpPtYhN3vriVz4OG',
#     'name': 'New Day & Cherry'},
#    'artists': [{'id': '5r4pQdeOkSMx1y2NNMDSlu', 'name': 'Devon Rea'},
#     {'id': '3b0TLzX6FkeQvv9daBtFBe', 'name': 'Goson'}],
#    'id': '2qT0WX3CvFVpG3cUQps2cy',
#    'name': 'New Day'}},
#  {'track': {'album': {'id': '765Itge0zLTWCqL0yFjUCS', 'name': 'Waves'},
#    'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#    'id': '4vjLw4yt3CHgzqkUY4PF9u',
#    'name': 'Waves'}},
#  {'track': {'album': {'id': '1zrNXYrLhmQXUVT1oDnqPX', 'name': 'first love'},
#    'artists': [{'id': '0mOeV01tlL7BQheKuD05LX', 'name': 'sweet palm'}],
#    'id': '30P5l9ftm4qtWQfTS6op2r',
#    'name': 'first love'}},
#  {'track': {'album': {'id': '1ygecBXoEnr62WfbrhnKXX', 'name': 'Odyssey'},
#    'artists': [{'id': '5BiHAcaswpfTQ4CQLQnGI5', 'name': 'Aerow'},
#     {'id': '0G0ttAARUNpc5aIAsUxXLZ', 'name': 'Mellow.'}],
#    'id': '4uy66poHcBJA80GbKFGpam',
#    'name': 'Purple Moon'}},
#  {'track': {'album': {'id': '4lKWekmYlSC9jzXqjdEcQf',
#     'name': 'air like perfume.'},
#    'artists': [{'id': '7r3gH36F9O5GtmYPYymtLK', 'name': 'coldbrew'}],
#    'id': '4nZY3o9EU0eOPTcjrbpkUt',
#    'name': 'air like perfume.'}},
#  {'track': {'album': {'id': '7cgUFRiQ822Nrfp4m10kOY', 'name': 'Azure'},
#    'artists': [{'id': '6DXpU6Gd2sctp0s2ryVNZA', 'name': 'Ellr'}],
#    'id': '5KNfKf13W6aVa3IGwWpkbN',
#    'name': 'Azure'}},
#  {'track': {'album': {'id': '5pfeNu6aJ2Y4Avt8hLdNby', 'name': 'Shoreline'},
#    'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#    'id': '248SKbigC5WrVxTZky8j3Q',
#    'name': 'Shoreline'}},
#  {'track': {'album': {'id': '492mx0k6jtTTwGkW0LCLXW', 'name': 'Express'},
#    'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'},
#     {'id': '52kTvSXed7Y3NB4X6MyXGf', 'name': 'Idepen'}],
#    'id': '26g7pUu82QepJJUR10RvBi',
#    'name': 'Express'}},
#  {'track': {'album': {'id': '4ARNxx6DDAqZ3LQ8OGkIEI', 'name': 'Flight 404'},
#    'artists': [{'id': '1BCaWmZ5a7IMTP5EFSPkfL', 'name': 'droemsk'},
#     {'id': '04zvEg1lhzzyN1rLgfO8hG', 'name': 'S-Ilo'},
#     {'id': '0L1eY5MVRiGxxfMa77yy3n', 'name': 'Jokujekku'}],
#    'id': '0iBydMPc0C7gL0B4XuEScG',
#    'name': 'Flight 404'}},
#  {'track': {'album': {'id': '10yRtUGfZxV8RjJm7jMcZO', 'name': 'The Mill'},
#    'artists': [{'id': '1K18BNpoYTlf251GQL1Mdz', 'name': 'Fayelo'}],
#    'id': '0hlyeFUF0LsDOj8PV0E2Vf',
#    'name': 'The Mill'}},
#  {'track': {'album': {'id': '0lGEG3nS1xtAGTb98IS0bv', 'name': 'Night Echo'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '3iGthn6RykA9JUHnilAIr0', 'name': 'Krynoze'}],
#    'id': '2FxmhQR0dQ3AbcY5zoBcnx',
#    'name': 'Night Echo'}},
#  {'track': {'album': {'id': '2HyoJhve44OmS3NE318eTu', 'name': 'Driftwood'},
#    'artists': [{'id': '7LdE7z3rYGOa0R4u6Ev7aG', 'name': 'Rinse Cycle'}],
#    'id': '1KcTcmiTkDRvCvSgx5j5Ba',
#    'name': 'Driftwood'}},
#  {'track': {'album': {'id': '4db3lAOSr8yk43RyX03pLk', 'name': 'Breathe In'},
#    'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#    'id': '3J8Ed5DcqfbPhf5cIlTZBU',
#    'name': 'Breathe In'}},
#  {'track': {'album': {'id': '1XpjOJgeUEt4UjMb1l7dEv', 'name': 'Marigold'},
#    'artists': [{'id': '0PbBgZYFayICVW0646NtXG', 'name': 'CMJ'}],
#    'id': '6o5JrW8DAmO6lFjfG3lirq',
#    'name': 'Marigold'}},
#  {'track': {'album': {'id': '5e4vR0uAxpgz7Dj0fITEyU', 'name': 'Folia'},
#    'artists': [{'id': '14xurMk6IfCAqEzI1txycG', 'name': 'Prinz Leo'},
#     {'id': '6VRAgC9krW0Ewz16KmTvZK', 'name': 'THAT KINDA VIBE'}],
#    'id': '00a5ijjVYSdEOEAmTTmTKG',
#    'name': 'Folia'}},
#  {'track': {'album': {'id': '7IROlKvDqqdlTkhZNRuVrk',
#     'name': 'For Tonight & Hopeful'},
#    'artists': [{'id': '5r4pQdeOkSMx1y2NNMDSlu', 'name': 'Devon Rea'},
#     {'id': '3b0TLzX6FkeQvv9daBtFBe', 'name': 'Goson'}],
#    'id': '4Ca6yyUJpcHujHGSvKPprg',
#    'name': 'For Tonight'}},
#  {'track': {'album': {'id': '1BEjv2GVteeJU5YKMcAtX1', 'name': 'Sunny Morning'},
#    'artists': [{'id': '2nlJrrVITo9CVbbBBHsiz5', 'name': 'Dreama'}],
#    'id': '16xkAXuFcdEd5VUHbDAMr6',
#    'name': 'Sunny Morning'}},
#  {'track': {'album': {'id': '17q6t75PVw0LcBAtZvWS00', 'name': 'Brightening'},
#    'artists': [{'id': '2SJLGPoAJhy9Id6N8oAftk', 'name': 'Juliàn'},
#     {'id': '3iGthn6RykA9JUHnilAIr0', 'name': 'Krynoze'}],
#    'id': '3SHMV8tJrcZGiMOgAt48F8',
#    'name': 'Brightening'}},
#  {'track': {'album': {'id': '4SiRQXdFEYRC0JZ6Gf32kH',
#     'name': 'Never The Same'},
#    'artists': [{'id': '7GsvnIE0bUBu6WZXO3ryJe', 'name': 'Sebastian Kamae'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '47EikapMb3zqYaFXkuz8Ub',
#    'name': 'Never The Same'}},
#  {'track': {'album': {'id': '3yFhvFNA9Wuc7f1Atpvb3X', 'name': 'Grandma'},
#    'artists': [{'id': '4KTl9YHavX4GehM7sDgHKr', 'name': 'JIrons'}],
#    'id': '6tdZyDiv9oQ8k8s4ezh6e8',
#    'name': 'Grandma'}},
#  {'track': {'album': {'id': '0woeCMmM7CpHgOmohOiASD', 'name': 'Looking Back'},
#    'artists': [{'id': '1ioPe940lafF8R9ejGRRpW', 'name': 'Enoki'}],
#    'id': '6XDaEkj49oZQ9ivXmsXVrZ',
#    'name': 'Looking Back'}},
#  {'track': {'album': {'id': '1ZiNxD3Mi0Sg6ORrtLxdZf', 'name': 'Seesaw'},
#    'artists': [{'id': '3oR6i8bFLe2JWAOWFEf7xz', 'name': 'DoublePercent'}],
#    'id': '7FEkxO6kVqFbUX9zm2XWhE',
#    'name': 'Seesaw'}},
#  {'track': {'album': {'id': '2PWowiMTiRnRFmLThlovgp', 'name': 'Sonder'},
#    'artists': [{'id': '4rgy5K4lHDLbaSC1MMuY5m', 'name': 'sinnr'},
#     {'id': '6CNlouXOE8j6UGHVmtagw6', 'name': 'Spinmont'}],
#    'id': '0e3Eh8wigW1HPYYt2SugTZ',
#    'name': 'Sonder'}},
#  {'track': {'album': {'id': '0rZW9igkkl9cl38eVeLDcR', 'name': 'Shining'},
#    'artists': [{'id': '2AneE7YpS3dgN9XjDgv2pO', 'name': 'Aoko'},
#     {'id': '4bkOWEgiKDhSsMCJGeAfxj', 'name': 'Jav Cast'}],
#    'id': '5nrR2VbzLIpdSbTniavPhW',
#    'name': 'Shining'}},
#  {'track': {'album': {'id': '5yX06p5aUvWDxMusXdHzO6', 'name': 'Morgen'},
#    'artists': [{'id': '0lh5lzZRrNVqtpfPTIkw2y', 'name': 'Vincent Krennerich'}],
#    'id': '3OU7FHDLRFoZh7anMwUCPA',
#    'name': 'Tiefblau'}},
#  {'track': {'album': {'id': '2BojgWgpcRgzOXd99HXui4', 'name': 'monterey'},
#    'artists': [{'id': '24PuTGiB6ISP3wErX3RzRT', 'name': 'CHASE STEPHEN'}],
#    'id': '5HZSnBCQKvfCRK96lUNt6V',
#    'name': 'monterey'}},
#  {'track': {'album': {'id': '3zqcBxINzRrMAHU3xJ5IwE', 'name': 'Up And Down'},
#    'artists': [{'id': '2SJLGPoAJhy9Id6N8oAftk', 'name': 'Juliàn'}],
#    'id': '6u4gvkwHQ8x8iLLSSGnHoZ',
#    'name': 'Up And Down'}},
#  {'track': {'album': {'id': '4jiywQHy2CDsMi32YJNphi', 'name': 'That Night'},
#    'artists': [{'id': '4CHVFfmgOpcOMB3d3B0uwO', 'name': 'Colours in Context'}],
#    'id': '6PP2oJo47Gxn7qAU9DWtHv',
#    'name': 'That Night'}},
#  {'track': {'album': {'id': '2fxoRdyO8G4dpco5eFBL71', 'name': 'Roadtrip'},
#    'artists': [{'id': '6UFQmSPDWaWReDLcCrPyNL', 'name': 'Early Garden'}],
#    'id': '4J99XW9Dca4hHhxslOaWwn',
#    'name': 'Roadtrip'}},
#  {'track': {'album': {'id': '3n9JHPdHK5j0P39q7xUAL9',
#     'name': 'birds out to play'},
#    'artists': [{'id': '7r3gH36F9O5GtmYPYymtLK', 'name': 'coldbrew'}],
#    'id': '0OXjb6VGGkenGDhAmJiXGc',
#    'name': 'birds out to play'}},
#  {'track': {'album': {'id': '3OSRCYmqTlckMPzt45L4kq', 'name': 'Tall'},
#    'artists': [{'id': '4OiOGOoUj1rFh8WmSREZey', 'name': 'ilaywho'}],
#    'id': '1kFNm3Y3Ry2veWoK6BDR1z',
#    'name': 'Tall'}},
#  {'track': {'album': {'id': '4MPHiV7la9yZ3Ybu26eaVd',
#     'name': 'freshflips 052021'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '38PTbKsLfXgSDIINnVBl8P', 'name': 'freshgoodies'}],
#    'id': '7d0jg10Wnb8dPdwPJgGnok',
#    'name': 'Spring Garden'}},
#  {'track': {'album': {'id': '4PLWYO8FjMSeWxYCLcpuNP',
#     'name': 'Dreams and Schemes'},
#    'artists': [{'id': '5Srat14VYy1jsG2vupuogv', 'name': 'David Tam'}],
#    'id': '3pSIxhrRjUAbtLEOfteDD0',
#    'name': 'Dreams and Schemes'}},
#  {'track': {'album': {'id': '1aJ062Scvz8QmdLlniLYML', 'name': 'Youth'},
#    'artists': [{'id': '4CHVFfmgOpcOMB3d3B0uwO', 'name': 'Colours in Context'},
#     {'id': '0iMWUBpWAGKAenBVePrZFP', 'name': 'Project AER'}],
#    'id': '4YA50O4gAlyeFr0CCBGFQ7',
#    'name': 'Youth'}},
#  {'track': {'album': {'id': '1KEi6Rff0xWN8f8PCdsHG8',
#     'name': 'a new beginning'},
#    'artists': [{'id': '7r3gH36F9O5GtmYPYymtLK', 'name': 'coldbrew'}],
#    'id': '6W6hjFe18mtTOEyc8GEJa7',
#    'name': 'a new beginning'}},
#  {'track': {'album': {'id': '7yrlqNul7x8jz2OT90Ooc8', 'name': 'Gentle Night'},
#    'artists': [{'id': '5jZeLexrrwGNUy6nv7tzdr', 'name': 'C4C'}],
#    'id': '2sJWWuWGTlxcMf3HDyCBzq',
#    'name': 'Gentle Night'}},
#  {'track': {'album': {'id': '2MrXOablHUwYzuW7Xs8xce', 'name': "Slip 'n Slide"},
#    'artists': [{'id': '68XfjORA2datUxlEUBwQQV', 'name': 'Anne Drew'},
#     {'id': '39lo8UU0LRMGTcHzmqMK9p', 'name': 'SunShun'}],
#    'id': '425gOBuquldfSIarKq4tzT',
#    'name': "Slip 'n Slide"}},
#  {'track': {'album': {'id': '5xDzCVfd8jfcH4qo3fsuQ5', 'name': 'Moonlight'},
#    'artists': [{'id': '3oR6i8bFLe2JWAOWFEf7xz', 'name': 'DoublePercent'}],
#    'id': '3WTrGUed4Ni2Fg3P5bWeco',
#    'name': 'Moonlight'}},
#  {'track': {'album': {'id': '6HPQfXJo8OFpyMxGjdIqbm', 'name': 'New Moon'},
#    'artists': [{'id': '59HCGLavl7XxBSiAdB2L8j', 'name': 'Hz.'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '2ZbvON6YdaYgcO1PiIA4uw',
#    'name': 'New Moon'}},
#  {'track': {'album': {'id': '3L6FN8rlrHaEf5AcM6DIR6', 'name': 'Serenity 2021'},
#    'artists': [{'id': '3vAvHFXAMYvfj5AO2CoYyX', 'name': 'Funcc.'},
#     {'id': '47OYz3d3DvnXpfaJ7i0z6b', 'name': 'Epifania'}],
#    'id': '4lYM3Ddwnz6vHQIVxtPAEk',
#    'name': 'Serendipity'}},
#  {'track': {'album': {'id': '0P7SIlPSll7dT2yOTZf0ej', 'name': 'Noodle House'},
#    'artists': [{'id': '61ZwgexUIZqT7ymSPsCW0H', 'name': 'Vannorte'}],
#    'id': '0IleR2MBZWzTYlLOW02jxZ',
#    'name': 'Noodle House'}},
#  {'track': {'album': {'id': '5vgHWGJaa3CgiZuw0x2WRi', 'name': 'Samurai'},
#    'artists': [{'id': '0BiIN25nWNSub42oUnFKoM', 'name': 'VINCENT MOON'},
#     {'id': '7j8hJ3AUvRVQp2J4eFxjVi', 'name': 'Farnell Newton'}],
#    'id': '3Rb52ZLcNvASaoprWY3KKA',
#    'name': 'Samurai'}},
#  {'track': {'album': {'id': '7uNrB3L5VZcMNOPXGaqnpa',
#     'name': 'Cabin Daydreams'},
#    'artists': [{'id': '7LdE7z3rYGOa0R4u6Ev7aG', 'name': 'Rinse Cycle'},
#     {'id': '6MvnyPinXRQbUCMsPoymhR', 'name': 'Lenny Loops'}],
#    'id': '2eBYHEV8IEfPsCYTxqpU0w',
#    'name': 'Cabin Daydreams'}},
#  {'track': {'album': {'id': '2IAM3OhY6Rfl1qeLrWJL4I',
#     'name': 'everything we had'},
#    'artists': [{'id': '4rAXFOfQ4Q5hwOF492tEuI', 'name': 'Vikram Dhakal'},
#     {'id': '6L9h5cN2DNOoMqFRgIv7uU', 'name': 'Banks'}],
#    'id': '2wRjgsdGXKMB7UdyhrFq8k',
#    'name': 'everything we had'}},
#  {'track': {'album': {'id': '79LnQ7KghS4P2SaSuGVkRt', 'name': 'Winter White'},
#    'artists': [{'id': '7nT0BfoHBOjL5yGLTRLmhm', 'name': 'CrazyJaZz'},
#     {'id': '5n9SautEmQzoC7G47NBta0', 'name': '.Eehou'},
#     {'id': '1YreDOGr8en691i5jQJJMK', 'name': 'Otis Ubaka'}],
#    'id': '0s3upcb2FRkUdAoeJwTqqO',
#    'name': 'Winter White'}},
#  {'track': {'album': {'id': '2K0M2K3cOIfXWEpVD8CcVA', 'name': 'Care Package'},
#    'artists': [{'id': '69NXAR2kpX8fv5ed7xJpgx', 'name': 'Maadrhino'},
#     {'id': '723wJl33DPwM2dF6n0rxaZ', 'name': 'Musqitone'}],
#    'id': '4Of7SxCmZXs7TtM9Qlwie6',
#    'name': 'Milk Tooth'}},
#  {'track': {'album': {'id': '7zsXXquownEgLT97g3ZYMk', 'name': 'winterglow'},
#    'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '0pjir6f0ROoeKVFsULDrAN',
#    'name': 'winterglow'}},
#  {'track': {'album': {'id': '4PCowd1WuaguRhdqZXbJ3R', 'name': 'equinox'},
#    'artists': [{'id': '4ApyJoQGYHAcMtJEvK5tRx', 'name': 'steezy prime'},
#     {'id': '0iMWUBpWAGKAenBVePrZFP', 'name': 'Project AER'}],
#    'id': '3vb60Ds1X9nnIgcmDedDeX',
#    'name': 'equinox'}},
#  {'track': {'album': {'id': '1MEl08VubrmP6PFQWEB0q3',
#     'name': 'forest lullaby'},
#    'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'},
#     {'id': '4bkOWEgiKDhSsMCJGeAfxj', 'name': 'Jav Cast'}],
#    'id': '7zc2FDuqxw5ooCAuTxhuYd',
#    'name': 'forest lullaby'}},
#  {'track': {'album': {'id': '40137huzteS9vC4gGX2UP8', 'name': 'La Paz Tape'},
#    'artists': [{'id': '7gVcXipsVVlTpZ8mMjzsJL', 'name': 'SP kOwi'},
#     {'id': '3WEutW4SLc7V9PiKTDM7bD', 'name': 'Bobby Dreamz BIG'}],
#    'id': '1Iu8iywvfaqrhE48hA9gzm',
#    'name': 'Miraflores'}},
#  {'track': {'album': {'id': '2ue91iJeMU7Cmo5G62qFNo', 'name': 'no vacancy'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '7BeR8KNgFQH30dZNVpZvJm',
#    'name': 'no vacancy'}},
#  {'track': {'album': {'id': '7JN5Ho0LxQwXkaP4Q9PgBk',
#     'name': 'Mellow Mornings'},
#    'artists': [{'id': '36L95dDAJG3EJ2tstIZpFj', 'name': 'Mr. Jello'},
#     {'id': '7j8hJ3AUvRVQp2J4eFxjVi', 'name': 'Farnell Newton'}],
#    'id': '3UiC8AF5jVDqAifEcQ2oDC',
#    'name': 'Mellow Mornings'}},
#  {'track': {'album': {'id': '3bP8E51JPSFQiZynfgBH7x', 'name': 'Snow Walk'},
#    'artists': [{'id': '6TsSBSisvQYCupsHmXe1iK', 'name': 'URCHN'},
#     {'id': '68XfjORA2datUxlEUBwQQV', 'name': 'Anne Drew'}],
#    'id': '3xzNluHOcDeu6AoR5gC3wJ',
#    'name': 'Snow Walk'}},
#  {'track': {'album': {'id': '4uuDHcmeaCTR8BmIVl15Hs', 'name': 'Nourish'},
#    'artists': [{'id': '68Re4wugc13HVak1p8Zawl', 'name': 'Yestalgia'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '1AtPzw458O0tAWDh5ch6Sj',
#    'name': 'Nourish'}},
#  {'track': {'album': {'id': '5YFzITz3FPAm7V3a2tTeI5', 'name': 'Bubba'},
#    'artists': [{'id': '7oc0u9Q0BkLat7c10fuHoF', 'name': 'Jr. Wellness'}],
#    'id': '30Ak0wMBgFEphMwMDQdY5t',
#    'name': 'Bubba'}},
#  {'track': {'album': {'id': '6rBnuL3apGfI42RaL9MJix',
#     'name': "you're not lost"},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '59HCGLavl7XxBSiAdB2L8j', 'name': 'Hz.'}],
#    'id': '0NIawAn7SZDA1CQ1G8GybR',
#    'name': "you're not lost"}},
#  {'track': {'album': {'id': '0evwpdvENzJNsIh0HdvDRB', 'name': 'Pulcro'},
#    'artists': [{'id': '15fMojo8Cll6nbSpkxSUJ9', 'name': 'lov lofi'}],
#    'id': '17G7wk2KmRyaqCeRBLMFqI',
#    'name': 'Pulcro'}},
#  {'track': {'album': {'id': '2ObFvn0oxuZGAkc4kBbaU2', 'name': 'Below Zero'},
#    'artists': [{'id': '2tqQ33SdGO1LqNg8DQDCio', 'name': 'SamuW'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '3dUNxiEf72V2en2nC9GOut',
#    'name': 'Below Zero'}},
#  {'track': {'album': {'id': '1TJPeChINkbSJs30JajvLG',
#     'name': 'bleak city kicks'},
#    'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'},
#     {'id': '4rgy5K4lHDLbaSC1MMuY5m', 'name': 'sinnr'}],
#    'id': '1FOZBPDXoDAJmmS4P28mHn',
#    'name': 'bleak city kicks'}},
#  {'track': {'album': {'id': '7B5y8VCLMguaqfOz6hf4T4',
#     'name': 'Tender Distance'},
#    'artists': [{'id': '0ccv58yNhOu5FERx9Kpvgt', 'name': 'Screen Jazzmaster'},
#     {'id': '2wWyy4LUiILXOvvCF0RSQk', 'name': 'BƱBBLE'}],
#    'id': '40SLOHt9f4Lny5xQfw1Yjs',
#    'name': 'Tender Distance'}},
#  {'track': {'album': {'id': '6baKei4M26hw5ofqPDCOUi', 'name': 'Overcast'},
#    'artists': [{'id': '2HTMpw5UmlJ2sUap8z5ZbU', 'name': 'kust'}],
#    'id': '5cx3PZ8RA0GnVo9Qfl9OXa',
#    'name': 'Overcast'}},
#  {'track': {'album': {'id': '3yrpXXPdpG76uRFMqUc4iW', 'name': 'December'},
#    'artists': [{'id': '3gpcXBhZOO75GyCOKTcudj', 'name': 'Magic Mondays'}],
#    'id': '5rCz97NoV0tGLbn49h3z0P',
#    'name': 'December'}},
#  {'track': {'album': {'id': '1MEl08VubrmP6PFQWEB0q3',
#     'name': 'forest lullaby'},
#    'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'},
#     {'id': '4bkOWEgiKDhSsMCJGeAfxj', 'name': 'Jav Cast'}],
#    'id': '7zc2FDuqxw5ooCAuTxhuYd',
#    'name': 'forest lullaby'}},
#  {'track': {'album': {'id': '4QOnz379zCxnZG6ZTTRS6h', 'name': 'i told you'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '0Zi66P67L2cB27PYfaeTA2',
#    'name': 'i told you'}},
#  {'track': {'album': {'id': '3oJaYMwIxRhPVuLk4NJLVW', 'name': 'Sirens'},
#    'artists': [{'id': '2E14TlP0N4RU8X3Y2i2Pq3', 'name': 'Slug'},
#     {'id': '42gnrsSSKKNNmfAJ0o3oyN', 'name': 'Soul Food Horns'}],
#    'id': '0j6JhzZ11YdmeV3RT3fKmZ',
#    'name': 'Sirens'}},
#  {'track': {'album': {'id': '6clT1ShdYH1XNZsjf7DA4m', 'name': 'Sailors'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '68Re4wugc13HVak1p8Zawl', 'name': 'Yestalgia'}],
#    'id': '0Titk4385TmeRWNFkTmvtN',
#    'name': 'Sailors'}},
#  {'track': {'album': {'id': '7lfhClmunN9igCRTCTvCsu', 'name': 'pick up'},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '3vzauVzDj3tFhhK0LuXaid',
#    'name': 'pick up'}},
#  {'track': {'album': {'id': '5jwXN0zduPh7pYUiIn1kCD', 'name': 'Lazy Sunday'},
#    'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#     {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#    'id': '0GI3utI1PXaCMiQTq1l3di',
#    'name': "Cruisin'"}},
#  {'track': {'album': {'id': '7zjk5CmvoP6k8M17vOrSc6', 'name': 'reality'},
#    'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'}],
#    'id': '6eGpjRTgqSs8JfLPJcSSts',
#    'name': 'reality'}},
#  {'track': {'album': {'id': '1CEXx43enUR3GPHIjbJr3V', 'name': 'laced'},
#    'artists': [{'id': '2cZLcgAsOeknY8nJGwt5Bg', 'name': 'mr.neab'}],
#    'id': '5bHTx6mM4twY8Vb7WYfwfZ',
#    'name': 'laced'}},
#  {'track': {'album': {'id': '54mdqR97pXFjdKjr1wlZMX', 'name': "i'm okay"},
#    'artists': [{'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'},
#     {'id': '6yxMxVw1MRLoB9EJWO5XVe', 'name': 'Theo Aabel'}],
#    'id': '3m4xFPXMUXsBlsjRwuHcFu',
#    'name': "i'm okay"}}]

# %% [markdown]
# Next is None, indicating that we have recieved all tracks in that playlist

# %%
print(len(all_items))
print(next)
# Out:
# 113
# None

# %% [markdown]
# Let's inspect the returned objects closer and extract some album and artist names

# %%
first_track_object = all_items[0]
first_track_object
# Out:
# {'track': {'album': {'id': '0c6GZXLOQNRRfoJSCraLwc', 'name': 'Pendulum'},
#   'artists': [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#    {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}],
#   'id': '5XfGPtiNkoPkeK00QTEHCb',
#   'name': 'Pendulum'}}

# %%
first_track = first_track_object["track"]
first_artists = first_track["artists"]
first_album = first_track["album"]

# %% [markdown]
# It seems that two artists collaborated on the first returned track

# %%
first_artists
# Out:
# [{'id': '0tquhVod10o2zf1ht2aVoz', 'name': 'Elior'},
#  {'id': '5MvvhhTGyd2iGzaksZpLEt', 'name': 'eaup'}]

# %%
import pandas as pd

columns = ["id", "name", "artist_id", "artist_name", "album_id", "album_name"]
track_df = pd.DataFrame(data=[], columns=columns)

for item in all_items:
    track = item["track"]
    track_id = track["id"]
    track_name = track["name"]

    artist = track["artists"][0]
    artist_id = artist["id"]
    artist_name = artist["name"]

    album = track["album"]
    album_id = album["id"]
    album_name = artist["name"]

    track_df = pd.concat([track_df, pd.DataFrame(data=[[track_id, track_name, artist_id, artist_name, album_id, album_name]], columns=columns)], axis=0)


track_df.set_index("id", inplace=True)
track_df
# Out:
#                                 name               artist_id  \
# id
# 5XfGPtiNkoPkeK00QTEHCb      Pendulum  0tquhVod10o2zf1ht2aVoz
# 0CVT6rpAdkDm4NKLdv7E9g      Cheer Up  5MvvhhTGyd2iGzaksZpLEt
# 1Kqx9kj7twQEexWCa4WHUZ  Endless Road  2RBJhPBOr8mI5evwaL4HR3
# 4ertsRlco2bn3dWqY41sxS       Fantasy  6CzaYsf8RIrCHNDhFGSfgm
# 0fO196iK1nt9tdoOLsn1pq         Ovina  14xurMk6IfCAqEzI1txycG
# ...                              ...                     ...
# 3vzauVzDj3tFhhK0LuXaid       pick up  5MvvhhTGyd2iGzaksZpLEt
# 0GI3utI1PXaCMiQTq1l3di      Cruisin'  0tquhVod10o2zf1ht2aVoz
# 6eGpjRTgqSs8JfLPJcSSts       reality  2cZLcgAsOeknY8nJGwt5Bg
# 5bHTx6mM4twY8Vb7WYfwfZ         laced  2cZLcgAsOeknY8nJGwt5Bg
# 3m4xFPXMUXsBlsjRwuHcFu      i'm okay  5MvvhhTGyd2iGzaksZpLEt
#
#                              artist_name                album_id  \
# id
# 5XfGPtiNkoPkeK00QTEHCb             Elior  0c6GZXLOQNRRfoJSCraLwc
# 0CVT6rpAdkDm4NKLdv7E9g              eaup  3W1TKjeKQawzmVlBGr9eOr
# 1Kqx9kj7twQEexWCa4WHUZ         Ghostnaut  04YdOVml7kXJN985zOOHPX
# 4ertsRlco2bn3dWqY41sxS  Havana Swim Club  4WjETwIOQcthrTokTKIOvL
# 0fO196iK1nt9tdoOLsn1pq         Prinz Leo  6tlATjYhVr3LhLZGBjtQmB
# ...                                  ...                     ...
# 3vzauVzDj3tFhhK0LuXaid              eaup  7lfhClmunN9igCRTCTvCsu
# 0GI3utI1PXaCMiQTq1l3di             Elior  5jwXN0zduPh7pYUiIn1kCD
# 6eGpjRTgqSs8JfLPJcSSts           mr.neab  7zjk5CmvoP6k8M17vOrSc6
# 5bHTx6mM4twY8Vb7WYfwfZ           mr.neab  1CEXx43enUR3GPHIjbJr3V
# 3m4xFPXMUXsBlsjRwuHcFu              eaup  54mdqR97pXFjdKjr1wlZMX
#
#                               album_name
# id
# 5XfGPtiNkoPkeK00QTEHCb             Elior
# 0CVT6rpAdkDm4NKLdv7E9g              eaup
# 1Kqx9kj7twQEexWCa4WHUZ         Ghostnaut
# 4ertsRlco2bn3dWqY41sxS  Havana Swim Club
# 0fO196iK1nt9tdoOLsn1pq         Prinz Leo
# ...                                  ...
# 3vzauVzDj3tFhhK0LuXaid              eaup
# 0GI3utI1PXaCMiQTq1l3di             Elior
# 6eGpjRTgqSs8JfLPJcSSts           mr.neab
# 5bHTx6mM4twY8Vb7WYfwfZ           mr.neab
# 3m4xFPXMUXsBlsjRwuHcFu              eaup
#
# [113 rows x 5 columns]

# %%
track_df[track_df["artist_name"] == "Elior"]
# Out:
#                               name               artist_id artist_name  \
# id
# 5XfGPtiNkoPkeK00QTEHCb    Pendulum  0tquhVod10o2zf1ht2aVoz       Elior
# 5KhoMiyDDs4vQazM6eE7jA   Calm Down  0tquhVod10o2zf1ht2aVoz       Elior
# 0pjir6f0ROoeKVFsULDrAN  winterglow  0tquhVod10o2zf1ht2aVoz       Elior
# 0GI3utI1PXaCMiQTq1l3di    Cruisin'  0tquhVod10o2zf1ht2aVoz       Elior
#
#                                       album_id album_name
# id
# 5XfGPtiNkoPkeK00QTEHCb  0c6GZXLOQNRRfoJSCraLwc      Elior
# 5KhoMiyDDs4vQazM6eE7jA  7HILhfhjOpTTtyYXMl5tqf      Elior
# 0pjir6f0ROoeKVFsULDrAN  7zsXXquownEgLT97g3ZYMk      Elior
# 0GI3utI1PXaCMiQTq1l3di  5jwXN0zduPh7pYUiIn1kCD      Elior

# %% [markdown]
# Elior is featured 4 times in the playlist
#
# Other endpoints to test:
# - [GET /audio_featres](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features)
# - [GET /users/{user_id}/playlists](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-list-users-playlists). Philipp's user_id is 31spovoympggn7jtvfw3a7bbyzma
